# %%
import gym
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# Configuration parameters for the whole setup
seed = 42
gamma = 0.99  # Discount factor for past rewards
max_steps_per_episode = 10000
env = gym.make("CartPole-v0")  # Create the environment
env.seed(seed)
eps = np.finfo(np.float32).eps.item()  # Smallest number such that 1.0 + eps != 1.0

num_inputs = 4
num_actions = 2
num_hidden = 128

inputs = layers.Input(shape=(num_inputs,))
common = layers.Dense(num_hidden, activation="relu")(inputs)
action = layers.Dense(num_actions, activation="softmax")(common)
critic = layers.Dense(1)(common)

model = keras.Model(inputs=inputs, outputs=[action, critic])

optimizer = keras.optimizers.Adam(learning_rate=0.007)
huber_loss = keras.losses.Huber()
action_probs_history = []
critic_value_history = []
rewards_history = []
running_reward = 0
episode_count = 0

while True:  # Run until solved
    state = env.reset()
    episode_reward = 0
    with tf.GradientTape() as tape:
        for timestep in range(1, max_steps_per_episode):
            # env.render(); Adding this line would show the attempts
            # of the agent in a pop up window.

            state = tf.convert_to_tensor(state)
            state = tf.expand_dims(state, 0)

            # Predict action probabilities and estimated future rewards
            # from environment state
            action_probs, critic_value = model(state)
            critic_value_history.append(critic_value[0, 0])

            # Sample action from action probability distribution
            action = np.random.choice(num_actions, p=np.squeeze(action_probs))
            action_probs_history.append(tf.math.log(action_probs[0, action]))

            # Apply the sampled action in our environment
            state, reward, done, _ = env.step(action)
            rewards_history.append(reward)
            episode_reward += reward

            if done:
                break

        # Update running reward to check condition for solving
        running_reward = 0.05 * episode_reward + (1 - 0.05) * running_reward

        # Calculate expected value from rewards
        # - At each timestep what was the total reward received after that timestep
        # - Rewards in the past are discounted by multiplying them with gamma
        # - These are the labels for our critic
        returns = []
        discounted_sum = 0
        for r in rewards_history[::-1]:
            discounted_sum = r + gamma * discounted_sum
            returns.insert(0, discounted_sum)

        # Normalize
        returns = np.array(returns)
        returns = (returns - np.mean(returns)) / (np.std(returns) + eps)
        returns = returns.tolist()

        # Calculating loss values to update our network
        history = zip(action_probs_history, critic_value_history, returns)
        actor_losses = []
        critic_losses = []
        for log_prob, value, ret in history:
            # At this point in history, the critic estimated that we would get a
            # total reward = `value` in the future. We took an action with log probability
            # of `log_prob` and ended up recieving a total reward = `ret`.
            # The actor must be updated so that it predicts an action that leads to
            # high rewards (compared to critic's estimate) with high probability.
            diff = ret - value
            actor_losses.append(-log_prob * diff)  # actor loss

            # The critic must be updated so that it predicts a better estimate of
            # the future rewards.
            critic_losses.append(
                huber_loss(tf.expand_dims(value, 0), tf.expand_dims(ret, 0))
            )

        # Backpropagation
        loss_value = sum(actor_losses) + sum(critic_losses)
        grads = tape.gradient(loss_value, model.trainable_variables)
        optimizer.apply_gradients(zip(grads, model.trainable_variables))

        # Clear the loss and reward history
        action_probs_history.clear()
        critic_value_history.clear()
        rewards_history.clear()

    # Log details
    episode_count += 1
    template = "running reward: {:.2f} at episode {}"
    print(template.format(running_reward, episode_count))

    if running_reward > 195:  # Condition to consider the task solved
        print("Solved at episode {}!".format(episode_count))
        break
# Out:
# 2022-02-27 16:35:58.080883: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-02-27 16:35:58.080912: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# /home/fulton/.local/lib/python3.9/site-packages/gym/envs/registration.py:505: UserWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1` with the environment ID `CartPole-v1`.
#   logger.warn(
# 2022-02-27 16:35:59.874397: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-27 16:35:59.875445: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-02-27 16:35:59.875669: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory
# 2022-02-27 16:35:59.875863: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory
# 2022-02-27 16:35:59.876056: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory
# 2022-02-27 16:35:59.876261: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory
# 2022-02-27 16:35:59.876468: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory
# 2022-02-27 16:35:59.876662: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory
# 2022-02-27 16:35:59.876847: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2022-02-27 16:35:59.876892: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# running reward: 1.10 at episode 1
# running reward: 1.65 at episode 2
# running reward: 3.31 at episode 3
# running reward: 4.00 at episode 4
# running reward: 8.10 at episode 5
# running reward: 8.84 at episode 6
# running reward: 9.90 at episode 7
# running reward: 10.86 at episode 8
# running reward: 12.11 at episode 9
# running reward: 13.56 at episode 10
# running reward: 14.63 at episode 11
# running reward: 14.45 at episode 12
# running reward: 15.93 at episode 13
# running reward: 15.68 at episode 14
# running reward: 15.74 at episode 15
# running reward: 15.66 at episode 16
# running reward: 15.42 at episode 17
# running reward: 15.15 at episode 18
# running reward: 14.90 at episode 19
# running reward: 14.80 at episode 20
# running reward: 16.31 at episode 21
# running reward: 17.20 at episode 22
# running reward: 17.59 at episode 23
# running reward: 17.46 at episode 24
# running reward: 19.03 at episode 25
# running reward: 19.08 at episode 26
# running reward: 18.73 at episode 27
# running reward: 20.49 at episode 28
# running reward: 21.42 at episode 29
# running reward: 21.15 at episode 30
# running reward: 20.89 at episode 31
# running reward: 22.09 at episode 32
# running reward: 22.04 at episode 33
# running reward: 22.09 at episode 34
# running reward: 21.88 at episode 35
# running reward: 21.34 at episode 36
# running reward: 20.82 at episode 37
# running reward: 20.28 at episode 38
# running reward: 21.32 at episode 39
# running reward: 21.00 at episode 40
# running reward: 21.00 at episode 41
# running reward: 21.00 at episode 42
# running reward: 20.65 at episode 43
# running reward: 20.22 at episode 44
# running reward: 19.91 at episode 45
# running reward: 19.86 at episode 46
# running reward: 19.37 at episode 47
# running reward: 19.20 at episode 48
# running reward: 18.79 at episode 49
# running reward: 18.95 at episode 50
# running reward: 18.90 at episode 51
# running reward: 19.31 at episode 52
# running reward: 18.89 at episode 53
# running reward: 18.60 at episode 54
# running reward: 18.42 at episode 55
# running reward: 18.15 at episode 56
# running reward: 18.44 at episode 57
# running reward: 19.37 at episode 58
# running reward: 19.95 at episode 59
# running reward: 20.15 at episode 60
# running reward: 20.94 at episode 61
# running reward: 20.35 at episode 62
# running reward: 20.13 at episode 63
# running reward: 19.87 at episode 64
# running reward: 19.63 at episode 65
# running reward: 19.65 at episode 66
# running reward: 20.12 at episode 67
# running reward: 19.96 at episode 68
# running reward: 19.96 at episode 69
# running reward: 19.81 at episode 70
# running reward: 19.42 at episode 71
# running reward: 19.45 at episode 72
# running reward: 19.68 at episode 73
# running reward: 19.35 at episode 74
# running reward: 19.03 at episode 75
# running reward: 18.93 at episode 76
# running reward: 18.63 at episode 77
# running reward: 18.45 at episode 78
# running reward: 18.73 at episode 79
# running reward: 18.69 at episode 80
# running reward: 18.66 at episode 81
# running reward: 18.87 at episode 82
# running reward: 18.88 at episode 83
# running reward: 18.84 at episode 84
# running reward: 19.34 at episode 85
# running reward: 19.23 at episode 86
# running reward: 18.82 at episode 87
# running reward: 18.57 at episode 88
# running reward: 18.35 at episode 89
# running reward: 20.03 at episode 90
# running reward: 19.98 at episode 91
# running reward: 19.63 at episode 92
# running reward: 20.05 at episode 93
# running reward: 19.79 at episode 94
# running reward: 21.50 at episode 95
# running reward: 21.33 at episode 96
# running reward: 20.91 at episode 97
# running reward: 20.87 at episode 98
# running reward: 20.57 at episode 99
# running reward: 20.75 at episode 100
# running reward: 21.21 at episode 101
# running reward: 21.55 at episode 102
# running reward: 21.67 at episode 103
# running reward: 22.84 at episode 104
# running reward: 23.49 at episode 105
# running reward: 23.82 at episode 106
# running reward: 24.13 at episode 107
# running reward: 23.82 at episode 108
# running reward: 26.98 at episode 109
# running reward: 26.28 at episode 110
# running reward: 26.12 at episode 111
# running reward: 25.76 at episode 112
# running reward: 25.72 at episode 113
# running reward: 26.49 at episode 114
# running reward: 26.41 at episode 115
# running reward: 26.29 at episode 116
# running reward: 25.78 at episode 117
# running reward: 25.74 at episode 118
# running reward: 27.80 at episode 119
# running reward: 31.71 at episode 120
# running reward: 32.78 at episode 121
# running reward: 36.34 at episode 122
# running reward: 36.52 at episode 123
# running reward: 36.99 at episode 124
# running reward: 36.75 at episode 125
# running reward: 35.81 at episode 126
# running reward: 39.07 at episode 127
# running reward: 40.26 at episode 128
# running reward: 41.00 at episode 129
# running reward: 42.20 at episode 130
# running reward: 42.94 at episode 131
# running reward: 42.39 at episode 132
# running reward: 41.82 at episode 133
# running reward: 42.73 at episode 134
# running reward: 44.70 at episode 135
# running reward: 45.16 at episode 136
# running reward: 44.85 at episode 137
# running reward: 44.81 at episode 138
# running reward: 44.92 at episode 139
# running reward: 45.72 at episode 140
# running reward: 47.59 at episode 141
# running reward: 49.56 at episode 142
# running reward: 49.93 at episode 143
# running reward: 52.28 at episode 144
# running reward: 53.22 at episode 145
# running reward: 54.26 at episode 146
# running reward: 57.70 at episode 147
# running reward: 60.11 at episode 148
# running reward: 61.06 at episode 149
# running reward: 60.00 at episode 150
# running reward: 58.05 at episode 151
# running reward: 65.15 at episode 152
# running reward: 63.84 at episode 153
# running reward: 62.45 at episode 154
# running reward: 63.43 at episode 155
# running reward: 61.66 at episode 156
# running reward: 60.27 at episode 157
# running reward: 58.56 at episode 158
# running reward: 61.28 at episode 159
# running reward: 59.57 at episode 160
# running reward: 62.69 at episode 161
# running reward: 67.31 at episode 162
# running reward: 65.94 at episode 163
# running reward: 64.89 at episode 164
# running reward: 63.20 at episode 165
# running reward: 63.49 at episode 166
# running reward: 62.61 at episode 167
# running reward: 63.28 at episode 168
# running reward: 61.77 at episode 169
# running reward: 60.93 at episode 170
# running reward: 60.48 at episode 171
# running reward: 58.86 at episode 172
# running reward: 57.77 at episode 173
# running reward: 56.78 at episode 174
# running reward: 56.29 at episode 175
# running reward: 55.38 at episode 176
# running reward: 54.36 at episode 177
# running reward: 52.79 at episode 178
# running reward: 52.70 at episode 179
# running reward: 53.41 at episode 180
# running reward: 54.59 at episode 181
# running reward: 58.11 at episode 182
# running reward: 58.36 at episode 183
# running reward: 58.99 at episode 184
# running reward: 59.39 at episode 185
# running reward: 60.12 at episode 186
# running reward: 60.17 at episode 187
# running reward: 65.81 at episode 188
# running reward: 66.67 at episode 189
# running reward: 71.03 at episode 190
# running reward: 72.73 at episode 191
# running reward: 75.49 at episode 192
# running reward: 76.22 at episode 193
# running reward: 78.21 at episode 194
# running reward: 77.80 at episode 195
# running reward: 77.41 at episode 196
# running reward: 78.84 at episode 197
# running reward: 82.45 at episode 198
# running reward: 86.72 at episode 199
# running reward: 86.39 at episode 200
# running reward: 85.77 at episode 201
# running reward: 84.48 at episode 202
# running reward: 85.66 at episode 203
# running reward: 85.32 at episode 204
# running reward: 86.56 at episode 205
# running reward: 88.78 at episode 206
# running reward: 94.34 at episode 207
# running reward: 96.42 at episode 208
# running reward: 97.70 at episode 209
# running reward: 102.82 at episode 210
# running reward: 103.18 at episode 211
# running reward: 104.27 at episode 212
# running reward: 105.45 at episode 213
# running reward: 108.83 at episode 214
# running reward: 108.29 at episode 215
# running reward: 108.23 at episode 216
# running reward: 107.11 at episode 217
# running reward: 106.96 at episode 218
# running reward: 105.51 at episode 219
# running reward: 105.33 at episode 220
# running reward: 105.22 at episode 221
# running reward: 107.06 at episode 222
# running reward: 111.70 at episode 223
# running reward: 107.32 at episode 224
# running reward: 107.40 at episode 225
# running reward: 112.03 at episode 226
# running reward: 113.73 at episode 227
# running reward: 111.89 at episode 228
# running reward: 113.10 at episode 229
# running reward: 115.30 at episode 230
# running reward: 114.93 at episode 231
# running reward: 115.88 at episode 232
# running reward: 115.24 at episode 233
# running reward: 115.83 at episode 234
# running reward: 116.74 at episode 235
# running reward: 118.50 at episode 236
# running reward: 118.17 at episode 237
# running reward: 119.42 at episode 238
# running reward: 121.94 at episode 239
# running reward: 118.05 at episode 240
# running reward: 120.10 at episode 241
# running reward: 121.49 at episode 242
# running reward: 123.12 at episode 243
# running reward: 125.36 at episode 244
# running reward: 128.19 at episode 245
# running reward: 129.78 at episode 246
# running reward: 133.29 at episode 247
# running reward: 136.63 at episode 248
# running reward: 139.80 at episode 249
# running reward: 137.46 at episode 250
# running reward: 140.58 at episode 251
# running reward: 143.56 at episode 252
# running reward: 146.38 at episode 253
# running reward: 147.71 at episode 254
# running reward: 150.32 at episode 255
# running reward: 150.96 at episode 256
# running reward: 152.46 at episode 257
# running reward: 150.79 at episode 258
# running reward: 144.80 at episode 259
# running reward: 140.56 at episode 260
# running reward: 134.68 at episode 261
# running reward: 129.15 at episode 262
# running reward: 127.64 at episode 263
# running reward: 125.31 at episode 264
# running reward: 123.04 at episode 265
# running reward: 121.39 at episode 266
# running reward: 117.27 at episode 267
# running reward: 112.71 at episode 268
# running reward: 108.72 at episode 269
# running reward: 106.63 at episode 270
# running reward: 103.70 at episode 271
# running reward: 103.52 at episode 272
# running reward: 100.89 at episode 273
# running reward: 102.55 at episode 274
# running reward: 107.42 at episode 275
# running reward: 107.35 at episode 276
# running reward: 107.33 at episode 277
# running reward: 106.71 at episode 278
# running reward: 111.38 at episode 279
# running reward: 111.11 at episode 280
# running reward: 114.45 at episode 281
# running reward: 116.13 at episode 282
# running reward: 118.43 at episode 283
# running reward: 118.75 at episode 284
# running reward: 118.82 at episode 285
# running reward: 122.13 at episode 286
# running reward: 126.02 at episode 287
# running reward: 126.37 at episode 288
# running reward: 126.75 at episode 289
# running reward: 128.16 at episode 290
# running reward: 131.75 at episode 291
# running reward: 135.17 at episode 292
# running reward: 138.41 at episode 293
# running reward: 141.49 at episode 294
# running reward: 144.41 at episode 295
# running reward: 147.19 at episode 296
# running reward: 149.83 at episode 297
# running reward: 152.34 at episode 298
# running reward: 154.72 at episode 299
# running reward: 156.99 at episode 300
# running reward: 159.14 at episode 301
# running reward: 161.18 at episode 302
# running reward: 163.12 at episode 303
# running reward: 164.97 at episode 304
# running reward: 166.72 at episode 305
# running reward: 168.38 at episode 306
# running reward: 169.96 at episode 307
# running reward: 171.47 at episode 308
# running reward: 172.89 at episode 309
# running reward: 174.25 at episode 310
# running reward: 175.53 at episode 311
# running reward: 176.76 at episode 312
# running reward: 177.92 at episode 313
# running reward: 179.02 at episode 314
# running reward: 180.07 at episode 315
# running reward: 181.07 at episode 316
# running reward: 182.02 at episode 317
# running reward: 182.92 at episode 318
# running reward: 183.77 at episode 319
# running reward: 184.58 at episode 320
# running reward: 185.35 at episode 321
# running reward: 186.08 at episode 322
# running reward: 181.58 at episode 323
# running reward: 182.50 at episode 324
# running reward: 183.38 at episode 325
# running reward: 177.16 at episode 326
# running reward: 178.30 at episode 327
# running reward: 179.38 at episode 328
# running reward: 180.42 at episode 329
# running reward: 181.39 at episode 330
# running reward: 176.27 at episode 331
# running reward: 177.46 at episode 332
# running reward: 172.14 at episode 333
# running reward: 173.53 at episode 334
# running reward: 174.85 at episode 335
# running reward: 172.56 at episode 336
# running reward: 169.68 at episode 337
# running reward: 169.60 at episode 338
# running reward: 171.12 at episode 339
# running reward: 172.56 at episode 340
# running reward: 169.99 at episode 341
# running reward: 168.14 at episode 342
# running reward: 169.73 at episode 343
# running reward: 169.14 at episode 344
# running reward: 170.69 at episode 345
# running reward: 172.15 at episode 346
# running reward: 169.69 at episode 347
# running reward: 171.21 at episode 348
# running reward: 172.65 at episode 349
# running reward: 174.02 at episode 350
# running reward: 175.32 at episode 351
# running reward: 176.55 at episode 352
# running reward: 174.07 at episode 353
# running reward: 175.37 at episode 354
# running reward: 176.60 at episode 355
# running reward: 177.77 at episode 356
# running reward: 178.88 at episode 357
# running reward: 179.94 at episode 358
# running reward: 180.94 at episode 359
# running reward: 181.89 at episode 360
# running reward: 182.80 at episode 361
# running reward: 183.66 at episode 362
# running reward: 184.48 at episode 363
# running reward: 176.45 at episode 364
# running reward: 168.28 at episode 365
# running reward: 169.87 at episode 366
# running reward: 167.22 at episode 367
# running reward: 168.86 at episode 368
# running reward: 170.42 at episode 369
# running reward: 171.90 at episode 370
# running reward: 173.30 at episode 371
# running reward: 174.64 at episode 372
# running reward: 171.46 at episode 373
# running reward: 172.88 at episode 374
# running reward: 174.24 at episode 375
# running reward: 175.53 at episode 376
# running reward: 176.75 at episode 377
# running reward: 177.91 at episode 378
# running reward: 178.72 at episode 379
# running reward: 179.78 at episode 380
# running reward: 180.79 at episode 381
# running reward: 181.45 at episode 382
# running reward: 182.38 at episode 383
# running reward: 183.26 at episode 384
# running reward: 184.10 at episode 385
# running reward: 184.39 at episode 386
# running reward: 184.57 at episode 387
# running reward: 184.09 at episode 388
# running reward: 175.69 at episode 389
# running reward: 174.46 at episode 390
# running reward: 171.63 at episode 391
# running reward: 164.25 at episode 392
# running reward: 163.14 at episode 393
# running reward: 161.48 at episode 394
# running reward: 159.71 at episode 395
# running reward: 157.67 at episode 396
# running reward: 155.74 at episode 397
# running reward: 154.20 at episode 398
# running reward: 152.44 at episode 399
# running reward: 145.62 at episode 400
# running reward: 144.19 at episode 401
# running reward: 142.53 at episode 402
# running reward: 142.15 at episode 403
# running reward: 141.59 at episode 404
# running reward: 141.12 at episode 405
# running reward: 135.41 at episode 406
# running reward: 135.44 at episode 407
# running reward: 134.52 at episode 408
# running reward: 129.84 at episode 409
# running reward: 130.15 at episode 410
# running reward: 130.89 at episode 411
# running reward: 131.05 at episode 412
# running reward: 130.84 at episode 413
# running reward: 130.35 at episode 414
# running reward: 130.83 at episode 415
# running reward: 130.84 at episode 416
# running reward: 130.45 at episode 417
# running reward: 131.38 at episode 418
# running reward: 126.06 at episode 419
# running reward: 126.21 at episode 420
# running reward: 126.60 at episode 421
# running reward: 122.07 at episode 422
# running reward: 123.91 at episode 423
# running reward: 124.37 at episode 424
# running reward: 125.55 at episode 425
# running reward: 125.92 at episode 426
# running reward: 128.78 at episode 427
# running reward: 129.64 at episode 428
# running reward: 131.50 at episode 429
# running reward: 133.08 at episode 430
# running reward: 135.28 at episode 431
# running reward: 138.26 at episode 432
# running reward: 140.30 at episode 433
# running reward: 142.23 at episode 434
# running reward: 145.12 at episode 435
# running reward: 147.87 at episode 436
# running reward: 150.47 at episode 437
# running reward: 152.95 at episode 438
# running reward: 155.20 at episode 439
# running reward: 157.44 at episode 440
# running reward: 159.57 at episode 441
# running reward: 161.59 at episode 442
# running reward: 163.51 at episode 443
# running reward: 165.34 at episode 444
# running reward: 167.07 at episode 445
# running reward: 168.72 at episode 446
# running reward: 170.28 at episode 447
# running reward: 171.77 at episode 448
# running reward: 173.18 at episode 449
# running reward: 174.52 at episode 450
# running reward: 175.79 at episode 451
# running reward: 177.00 at episode 452
# running reward: 178.15 at episode 453
# running reward: 179.25 at episode 454
# running reward: 180.28 at episode 455
# running reward: 181.27 at episode 456
# running reward: 182.21 at episode 457
# running reward: 183.10 at episode 458
# running reward: 183.94 at episode 459
# running reward: 184.74 at episode 460
# running reward: 185.51 at episode 461
# running reward: 186.23 at episode 462
# running reward: 186.92 at episode 463
# running reward: 187.57 at episode 464
# running reward: 188.19 at episode 465
# running reward: 188.78 at episode 466
# running reward: 189.35 at episode 467
# running reward: 189.88 at episode 468
# running reward: 190.38 at episode 469
# running reward: 190.87 at episode 470
# running reward: 191.32 at episode 471
# running reward: 191.76 at episode 472
# running reward: 192.17 at episode 473
# running reward: 192.56 at episode 474
# running reward: 192.93 at episode 475
# running reward: 193.29 at episode 476
# running reward: 193.62 at episode 477
# running reward: 193.94 at episode 478
# running reward: 194.24 at episode 479
# running reward: 194.53 at episode 480
# running reward: 194.80 at episode 481
# running reward: 195.06 at episode 482
# Solved at episode 482!

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 from keras.utils import plot_model
#       2 plot_model(model)
#
# ImportError: cannot import name 'plot_model' from 'keras.utils' (/home/fulton/.local/lib/python3.9/site-packages/keras/utils/__init__.py)
